# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavoandrade811-beep/Projeto-Integrador2/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

dias = ["Seg", "Ter", "Qua", "Qui", "Sex", "Sab", "Dom"]
temperatura_media = [24.5, 25.1, 23.8, 26.3, 27.0, 28.2, 26.8]

# %%
plt.figure(figsize=(10, 6))
plt.plot(dias, temperatura_media, marker='o', linestyle='-', color='b')
plt.title('Temperatura Média Semanal')
plt.xlabel('Dia da Semana')
plt.ylabel('Temperatura Média (°C)')
plt.grid(True)
plt.show()
